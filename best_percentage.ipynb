# %%
import numpy as np
import matplotlib.pyplot as plt

#This data is just the output of best_percentage_founder
data = [(5.0, 96.86294416243652), (10.0, 96.85522788203757), (15.000000000000002, 96.85511363636363), (20.0, 96.86144578313252), (25.0, 96.9324758842444), (30.0, 96.83103448275862), (35.0, 96.88148148148146), (40.0, 96.84337349397592), (44.99999999999999, 96.76754385964908), (49.99999999999999, 96.81250000000001), (54.99999999999999, 96.82352941176472), (60.0, 96.72891566265062), (65.0, 96.96551724137933), (70.0, 96.85600000000001), (75.00000000000001,
96.6923076923077), (80.00000000000001, 96.97590361445783), (85.00000000000001, 97.23809523809524), (90.00000000000003, 96.83333333333334), (95.00000000000003, 96.28571428571428)]
# Unpack the data into separate lists
percentages, accuracies = zip(*data)

# Plot the data
plt.plot(percentages, accuracies, marker='o', linestyle='-', color='b')
plt.title('Accuracy vs Percentage')
plt.xlabel('Percentage of training data')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
